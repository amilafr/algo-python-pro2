# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro2/blob/main/M1L1_Review_Algorithms_and_data_structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Review. Algorithms and data structures
#
# [PPT M1L1 ENG](https://docs.google.com/presentation/d/15PycIYaErok8IqS8VNJsdwG18oL8tIszdfmnqkMLfjM/edit?usp=sharing)
#
# [PPT M1L1 IND](https://docs.google.com/presentation/d/1RKIPiVSC7bfn8JvK-QjBDi56e_6srcj3xnp26r_xI_s/edit?usp=sharing)

# %% [markdown]
# # variables, conditions, and loops

# %% [markdown]
# ## Data Types, Functions, and Operators

# %% [markdown]
# ### Data Types

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# int --> bilangan bulat
num_int = 30

# float --> bilangan desimal
num_float = 9.78

# str --> string, ditandai dengan '' atau ""
str1 = "Hello"
str2 = "2024.07.07"
str3 = "$#*nn.."

# bool --> boolean, logical type : True/False
bool1 = True
bool2 = False

# %%
# list --> kumpulan data yg urut (index) dan sama tipenya
my_list = [1, 2, 3, 4, 5, 1, 1]
my_list2 = ['a', 'b', 'c']

# dict --> dictionary : key-value pair
my_dict = {
    'name' : 'John',
    'age' : 17,
    'birthdate' : '2007.01.01'
}

# set --> himpunan : unique elements
my_set = {1, 1, 2, 3, 3}

print(my_list)
print(my_list2)
print(my_dict)
print(my_set)
# Out:
# [1, 2, 3, 4, 5, 1, 1]
# ['a', 'b', 'c']
# {'name': 'John', 'age': 17, 'birthdate': '2007.01.01'}
# {1, 2, 3}

# %% [markdown]
# ### Functions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('Hello my friend!')

age = input('Your age: ')

age_int = int(age)
age_float = float(age)

print(age_int)
print(age_float)
# Out:
# Hello my friend!
# Your age: 10
# 10
# 10.0

# %%
num = 40

result = 'hi' + str(num)
result_length = len(result)

print(result)
print(result_length)
# Out:
# hi40
# 4

# %% [markdown]
# ### Operators

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 4
b = 2

jumlah = a+b # penjumlahan
kurang = a-b # pengurangan
kali = a*b # perkalian
bagi_no_koma = a//b # pembagian tanpa koma (int)
bagi_koma = a/b # pembagian dengan koma (float)
sisa_bagi = a%b # sisa hasil bagi
pangkat = a**b # a pangkat b

print('+', jumlah)
print('-', kurang)
print('*', kali)
print('//', bagi_no_koma)
print('/', bagi_koma)
print('%', sisa_bagi)
print('**', pangkat)
# Out:
# + 6
# - 2
# * 8
# // 2
# / 2.0
# % 0
# ** 16

# %% [markdown]
# ### example

# %%
who ='Y Combinator'

current_year = input('What year is it now?')
current_year = int(current_year)

foundation_year = 2005
age = current_year - foundation_year

print(who,'came into being', age, 'years ago')
# Out:
# What year is it now?2024
# Y Combinator came into being 19 years ago

# %% [markdown]
# ## Condition/Kondisi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ans = input('Please insert code: ')

if ans == 'a':
  print('A')
elif ans == 'b':
  print('B')
elif ans == 'c':
  print('C')
else:
  print('E')
# Out:
# Please insert code: z
# E

# %% [markdown]
# ### example

# %%
# from projects in World of Code, choose the ones that you like the most
project = input('Enter a World of Code module (development or data analysis):')
project = project.lower()

if project == 'development':
   print('Great! Get ready for 3D games, apps, and websites!')
else:
   print('Nice! You will be working with data and machine learning!')
# Out:
# Enter a World of Code module (development or data analysis):development
# Great! Get ready for 3D games, apps, and websites!

# %% [markdown]
# ## Loops/Perulangan

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### while loop

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# while --> perulangan tidak terbatas (selama kondisi benar)

ans = input('Insert code (off - stop): ').lower()

while ans != 'off': # selama ans != 'off' --> ngulang terus
  print(ans)
  ans = input('Insert code (off - stop): ').lower()
# Out:
# Insert code (off - stop): hai
# hai
# Insert code (off - stop): halo
# halo
# Insert code (off - stop): kkk
# kkk
# Insert code (off - stop): off

# %% [markdown]
# ### for loop

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
kata = [1, 2, 3, 4]

for i in kata:
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
# for --> perulangan terbatas (sudah ditentukan berapa kalinya)
kalimat = 'I love python'

for huruf in kalimat: # perulangan sesuai jumlah elemen
  print(huruf)
# Out:
# I
#
# l
# o
# v
# e
#
# p
# y
# t
# h
# o
# n

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# mengulang sebanyak 3x
for i in range(3):
  print("halo")
# Out:
# halo
# halo
# halo

# %%
for i in range(5): # berulang 5x
  print(i, '- hai')
# Out:
# 0 - hai
# 1 - hai
# 2 - hai
# 3 - hai
# 4 - hai

# %%
for i in range(1, 5): # i nya --> 1 sampai 4 (< 5)
  print(i, '- halo')
# Out:
# 1 - halo
# 2 - halo
# 3 - halo
# 4 - halo

# %% [markdown]
# # lists and dictionaries

# %% [markdown]
# ## List

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_string = 'a b c'
my_list = my_string.split()

print(my_list[0])
# Out:
# a

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in my_list:
  print(i)
# Out:
# a
# b
# c

# %%
print('a' in my_list)
# Out:
# True

# %%
my_list = ['2', '3', '3']
my_list = list(map(int, my_list))

print(my_list)
# Out:
# [2, 3, 3]

# %% [markdown]
# ### example

# %%
# split string jadi list
income = input('Enter monthly income data').split()

# semua elemen di list income jadi integer
income = list(map(int, income))

total = 0

minimum = income[0]
maximum = income[0]

for item in income:
    total += item
    if item > maximum:
        maximum = item
    if item < minimum:
        minimum = item

print('Total earnings:', total)
print('Maximum earnings:', maximum)
print('Minimum earnings:', minimum)
# Out:
# Enter monthly income data10 10 20
# Total earnings: 40
# Maximum earnings: 20
# Minimum earnings: 10

# %% [markdown]
# ## Dictionary

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data = {
    'nama' : 'Rakha',
    'umur' : 16
}

print(data.keys())
print(data.values())
print(data['nama'])
# Out:
# dict_keys(['nama', 'umur'])
# dict_values(['Rakha', 16])
# Rakha

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### example

# %%
data = dict()
amount = int(input('Enter the number of startups'))

for i in range(amount):
    name = input('Enter startup name')
    data[name] = dict()
    data[name]['founder'] = input('Enter founder name')
    data[name]['investments'] = int(input('Investments attracted:'))

max_investments = 0

for startup in data:
    if data[startup]['investments'] > max_investments:
        max_investments = data[startup]['investments']
        winner = startup

print('Most investments attracted by', winner)
print('Founder:', data[winner]['founder'])
print('Total investments:', data[winner]['investments'])
# Out:
# Enter the number of startups2
# Enter startup nameamila
# Enter founder nameamila
# Investments attracted:10
# Enter startup nameaiko
# Enter founder nameakiko
# Investments attracted:20
# Most investments attracted by aiko
# Founder: akiko
# Total investments: 20
