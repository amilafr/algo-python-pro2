# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro2/blob/main/M3L5_Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data visualization
#
# [PPT M3L5 ENG](https://docs.google.com/presentation/d/1r4VYW7TYHtZBmiOaNpZnYZMd2W_ZBvyUy-t4wOxopDI/edit?usp=sharing)
#
# [PPT M3L5 IND](https://docs.google.com/presentation/d/1twHHSVcpm47aZTN3TBar5nJZocR1NAb6Tkrx5JM7uNs/edit?usp=sharing)

# %% [markdown]
# pie charts;
# linear graphs;
# bar charts;
# and many others...

# %%
# import library

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Linear Graph
#
# data time series --> seiring berjalannya waktu

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_series = pd.Series(
    index = [1, 2, 3, 4, 5],
    data = [10, 10, 20, 40, 30]
)

data_series.plot() # bikin grafik
plt.show() # menampilkan

# %%
import pandas as pd
import matplotlib.pyplot as plt

s = pd.Series(
    data = [10, 5, 15, 20, 10],
    index = [1, 2, 3, 4, 5]
    )

s.plot()
plt.show()

# %%
# bikin dataframe

df = pd.read_csv('GoogleApps.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size    Installs  Type  Price Content Rating      Last Updated  \
# 0      159  19.0     10000.0  Free    0.0       Everyone   January 7, 2018
# 1      967  14.0    500000.0  Free    0.0       Everyone  January 15, 2018
# 2    87510   8.7   5000000.0  Free    0.0       Everyone    August 1, 2018
# 3   215644  25.0  50000000.0  Free    0.0           Teen      June 8, 2018
# 4      967   2.8    100000.0  Free    0.0       Everyone     June 20, 2018
#
#           Current Ver   Android Ver
# 0               1.0.0  4.0.3 and up
# 1               2.0.0  4.0.3 and up
# 2               1.2.4  4.0.3 and up
# 3  Varies with device    4.2 and up
# 4                 1.1    4.4 and up

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             7352 non-null   object
#  1   Category        7352 non-null   object
#  2   Rating          7352 non-null   float64
#  3   Reviews         7352 non-null   int64
#  4   Size            7352 non-null   float64
#  5   Installs        7352 non-null   float64
#  6   Type            7352 non-null   object
#  7   Price           7352 non-null   float64
#  8   Content Rating  7352 non-null   object
#  9   Last Updated    7352 non-null   object
#  10  Current Ver     7352 non-null   object
#  11  Android Ver     7352 non-null   object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 689.4+ KB

# %% [markdown]
# ## Histogram
#
# distribusi data dari minimum - maximum

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['Rating'].plot(kind='hist') # default --> range dibagi jadi 10
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Size'].plot(kind = 'hist', color = "yellow")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Size'].plot(kind = 'hist', bins = 5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# histogram size yang rating > 3

df[df['Rating'] > 3]['Size'].plot(kind='hist')

# df['Size'].plot(kind = 'hist', bins = 5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Boxplot
#
# median, q1, q3, minimum, maximum, outlier (data yang beda sendiri)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['Size'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df[df['Type'] == 'Paid']['Size'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Scatter Plot
#
# nunjukin hubungan antara x sama y

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Constructing Scatter Plot**
#
# - Select the two attributes we need to visualize the relationship between.
# - Mark the points on the coordinate plane whose coordinates represent the values of the selected attributes.
# - Evaluate the position of the points on the graph: are they scattered evenly along the coordinate plane, or do they cluster around an imaginary line?
# - If the points are clustered around an imaginary line, there is a connection between the quantities; if they are not, there is no connection.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# hubungannya rating sama install
df.plot(x = 'Rating', y = 'Installs', kind = 'scatter')
# Out:
# <Axes: xlabel='Rating', ylabel='Installs'>

# %%
# hubungannya rating sama jumlah reviews
df.plot(x = 'Rating', y = 'Reviews', kind = 'scatter')
# Out:
# <Axes: xlabel='Rating', ylabel='Reviews'>

# %%
df.plot(kind = 'scatter', x = 'Rating', y = 'Reviews')
# Out:
# <Axes: xlabel='Rating', ylabel='Reviews'>

# %% [markdown]
# rating sama jumlah install gaada hubungannya

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pie Charts

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['Category'].value_counts()
# Out:
# Category
# FAMILY                 1574
# GAME                    911
# TOOLS                   631
# MEDICAL                 318
# LIFESTYLE               275
# PERSONALIZATION         270
# FINANCE                 266
# BUSINESS                246
# SPORTS                  245
# PRODUCTIVITY            234
# PHOTOGRAPHY             231
# HEALTH_AND_FITNESS      216
# COMMUNICATION           206
# SHOPPING                176
# NEWS_AND_MAGAZINES      162
# TRAVEL_AND_LOCAL        159
# BOOKS_AND_REFERENCE     142
# SOCIAL                  142
# VIDEO_PLAYERS           114
# EDUCATION               108
# MAPS_AND_NAVIGATION      94
# FOOD_AND_DRINK           84
# ENTERTAINMENT            84
# AUTO_AND_VEHICLES        63
# LIBRARIES_AND_DEMO       61
# ART_AND_DESIGN           58
# HOUSE_AND_HOME           56
# WEATHER                  51
# PARENTING                43
# COMICS                   42
# EVENTS                   38
# BEAUTY                   36
# DATING                   16
# Name: count, dtype: int64

# %%
df['Category'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# create a pie chart reflecting the distribution of updates by season
df['Type'].value_counts()
# Out:
# Type
# Free    6789
# Paid     563
# Name: count, dtype: int64

# %%
df['Type'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Content Rating'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['Category'].value_counts()
# Out:
# Category
# FAMILY                 1574
# GAME                    911
# TOOLS                   631
# MEDICAL                 318
# LIFESTYLE               275
# PERSONALIZATION         270
# FINANCE                 266
# BUSINESS                246
# SPORTS                  245
# PRODUCTIVITY            234
# PHOTOGRAPHY             231
# HEALTH_AND_FITNESS      216
# COMMUNICATION           206
# SHOPPING                176
# NEWS_AND_MAGAZINES      162
# TRAVEL_AND_LOCAL        159
# BOOKS_AND_REFERENCE     142
# SOCIAL                  142
# VIDEO_PLAYERS           114
# EDUCATION               108
# MAPS_AND_NAVIGATION      94
# FOOD_AND_DRINK           84
# ENTERTAINMENT            84
# AUTO_AND_VEHICLES        63
# LIBRARIES_AND_DEMO       61
# ART_AND_DESIGN           58
# HOUSE_AND_HOME           56
# WEATHER                  51
# PARENTING                43
# COMICS                   42
# EVENTS                   38
# BEAUTY                   36
# DATING                   16
# Name: count, dtype: int64

# %%
df['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
df['Category'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Category'>

# %%
df['Category'].value_counts().plot(kind='barh', figsize=(10, 6))
# Out:
# <Axes: ylabel='Category'>

# %%
df['Category'].value_counts().plot(kind='barh', figsize=(8, 5), grid = True)
# Out:
# <Axes: ylabel='Category'>

# %%
# nampilin rata2 'Installs' yang free tapi dikelompokin berdasarkan 'Content Rating'
data1 = df[df['Type'] == 'Free'].groupby(by = 'Content Rating')['Installs'].mean()

print(data1)
# Out:
# Content Rating
# Everyone        7.259786e+06
# Everyone 10+    3.535636e+07
# Teen            1.486967e+07
# Name: Installs, dtype: float64

# %%
data1.plot(kind='barh')
# Out:
# <Axes: ylabel='Content Rating'>

# %%
d2 = df[df['Type'] == 'Paid'].groupby(by = 'Content Rating')['Installs'].mean()
print(d2)
# Out:
# Content Rating
# Everyone         53837.631902
# Everyone 10+    147150.000000
# Teen            125828.863636
# Name: Installs, dtype: float64

# %%
d2.plot(kind='barh')
# Out:
# <Axes: ylabel='Content Rating'>

# %%
data_pivot = df.pivot_table(
    index='Content Rating',
    columns='Type',
    values='Installs',
    aggfunc='mean'
)

print(data_pivot)
# Out:
# Type                    Free           Paid
# Content Rating
# Everyone        7.259786e+06   53837.631902
# Everyone 10+    3.535636e+07  147150.000000
# Teen            1.486967e+07  125828.863636

# %%
data_pivot.plot(kind='barh', subplots=True)
# Out:
# array([<Axes: title={'center': 'Free'}, ylabel='Content Rating'>,
#        <Axes: title={'center': 'Paid'}, ylabel='Content Rating'>],
#       dtype=object)

# %%
data_pivot.plot(kind='barh', subplots=True, layout=(1, 2)) # (row, column)
# Out:
# array([[<Axes: title={'center': 'Free'}, ylabel='Content Rating'>,
#         <Axes: title={'center': 'Paid'}, ylabel='Content Rating'>]],
#       dtype=object)

# %%
data_pivot.plot(kind='barh', subplots=True, layout=(1, 2), sharey=True, grid=True)
# Out:
# array([[<Axes: title={'center': 'Free'}, ylabel='Content Rating'>,
#         <Axes: title={'center': 'Paid'}, ylabel='Content Rating'>]],
#       dtype=object)

# %%
data_pivot.plot(kind = 'bar', subplots = True)
# Out:
# array([<Axes: title={'center': 'Free'}, xlabel='Content Rating'>,
#        <Axes: title={'center': 'Paid'}, xlabel='Content Rating'>],
#       dtype=object)

# %%
data_pivot.plot(kind = 'barh')
# Out:
# <Axes: ylabel='Content Rating'>

# %% [markdown]
# # Example

# %%
#write your code here
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('StudentsPerformance.csv')

# df.info()
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['mean score'] = (df['math score'] + df['reading score'] + df['writing score']) / 3

df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    mean score
# 0   72.666667
# 1   82.333333
# 2   92.666667
# 3   49.333333
# 4   76.333333

# %% [markdown]
# ## linear graph

# %%
df['mean score'].plot(kind='line')
# Out:
# <Axes: >

# %% [markdown]
# ## histogram

# %%
df['math score'].plot(kind='hist') # persebaran data math score
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['reading score'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['writing score'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['mean score'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## boxplot

# %%
df[df['test preparation course'] == 'completed']['mean score'].plot(kind = 'box') # median, dll nya mean score yang test = completed
# Out:
# <Axes: >

# %%
df[df['test preparation course'] == 'none']['mean score'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ## scatter plot

# %%
df.plot(x = 'math score', y = 'reading score', kind = 'scatter')
# hubungannya math score sama reading score --> yg math score nya tinggi biasanya readingnya juga tinggi
# Out:
# <Axes: xlabel='math score', ylabel='reading score'>

# %%
df.plot(x = 'math score', y = 'writing score', kind = 'scatter')
# Out:
# <Axes: xlabel='math score', ylabel='writing score'>

# %% [markdown]
# ## pie chart

# %%
df['parental level of education'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['test preparation course'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## bar chart

# %%
# rata2 score per test preparation dan parental
d = df.pivot_table(
    index = 'parental level of education',
    columns = 'test preparation course',
    values = 'mean score',
    aggfunc = 'mean'
    )

d
# Out:
# test preparation course      completed       none
# parental level of education
# associate's degree           74.939024  66.423810
# bachelor's degree            76.239130  69.166667
# high school                  66.964286  61.550000
# master's degree              76.316667  72.205128
# some college                 74.653680  65.284116
# some high school             69.337662  61.915033

# %%
d.plot(kind = 'barh', grid = True)
# Out:
# <Axes: ylabel='parental level of education'>
