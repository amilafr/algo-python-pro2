# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro2/blob/main/M1L2_Review_Functions_and_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Review. Functions and OOP
#
# [PPT M1L2 ENG](https://docs.google.com/presentation/d/11V0-nSZyFxf0oZXcdfUBegkmumK2aykO39-svJqWVhU/edit?usp=sharing)
#
# [PPT M1L2 IND](https://docs.google.com/presentation/d/1i3VxAPtVqRKSZ_YHUFGf3e0Vh6eB65slJQXVWczSMJw/edit?usp=sharing)

# %% [markdown]
# # IND

# %% [markdown]
# ## A. Fungsi

# %% [markdown]
# ### Fungsi di Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('halooo')
# Out:
# halooo

# %%
preferensi = input('Masukkan preferensi:')

print('maunya', preferensi)
# Out:
# Masukkan preferensi:makanan
# maunya makanan

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pengembalian Nilai

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# fungsi tidak mengembalikan nilai
print(4 + 5)
# Out:
# 9

# %%
print('halo')
# Out:
# halo

# %%
# mengembalikan nilai
# len() --> panjang string atau struktur data

kalimat = 'selamat malam'
panjang = len(kalimat) # integer

print(panjang)
# Out:
# 13

# %%
list_angka = [2, 3, 3, 4]

print(len(list_angka))
# Out:
# 4

# %% [markdown]
# ### Membuat Fungsi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# tidak mengembalikan nilai
def print_data(): # tanpa parameter
    print('halooo')
    print('haiii')
    print('selamat malam')

# manggil fungsi
print_data()

print_data()
# Out:
# halooo
# haiii
# selamat malam
# halooo
# haiii
# selamat malam

# %%
def print_data(nama, umur): # dengan parameter
    print('nama:', nama)
    print('umur:', umur)
    print('selamat malam')

# manggil fungsi
print_data('jack', 15)
# Out:
# nama: jack
# umur: 15
# selamat malam

# %%
# mengembalikan nilai
def penjumlahan(a, b):
    hasil = a + b
    return hasil # nilai yang dikembalikan

result = penjumlahan(2, 3)
print(result)
# Out:
# 5

# %% [markdown]
# ## B. OOP

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# bikin class --> template untuk kita membuat objek
class Mobil():
    # constructor
    def __init__(self, warna, merk):
        # properti
        # self --> merujuk ke objek/instance itu sendiri
        self.warna = warna
        self.merk = merk

    # metode
    def maju(self):
        print('mobil', self.warna, 'maju')

    def print_data(self):
        print('warna:', self.warna)
        print('merk:', self.merk)

# membuat objek (instance class)
# nama_objek = nama_class(...)
mobil_merah = Mobil('merah', 'toyota')

# menggunakan metode di objek
mobil_merah.maju()
# Out:
# mobil merah maju

# %%
mobil_hitam = Mobil('hitam', 'honda')

mobil_hitam.maju()
mobil_hitam.print_data()
# Out:
# mobil hitam maju
# warna: hitam
# merk: honda

# %% [markdown]
# ## C. Parameter **kwargs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def print_data(data, nama):
    print(data)
    print(nama)

print_data('kkkk', 'amila', 40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3298/577951005.py in <cell line: 0>()
#       3     print(nama)
#       4
# ----> 5 print_data('kkkk', 'amila', 40)
#
# TypeError: print_data() takes 2 positional arguments but 3 were given

# %%
def print_data(data):
    for key in data:
        print(key, '-', data[key])

data = {
    'nama': 'Amila',
    'umur': 17
}

# panggil fungsi
print_data(data)
# Out:
# nama - Amila
# umur - 17

# %%
# fungsi **kwargs
def print_data(nama, **kwargs):
    print('nama:', nama)

    for key in kwargs:
        print(key, '-', kwargs[key])

# panggil fungsi
print_data('rachel', umur=16, alamat='jakarta', hobi='main game')
# Out:
# nama: rachel
# umur - 16
# alamat - jakarta
# hobi - main game

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ENG

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Functions in Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# fungsi print --> print
print('Halooo')
# Out:
# Halooo

# %%
# input() --> input data lewat keyboard
nama = input('Masukkan nama:')

print('Namaku', nama)
# Out:
# Masukkan nama:frida
# Namaku frida

# %%
# konversi tipe data

angka = int(input('Masukkan angka: ')) # int() --> jadi int

print(angka + 10)
# Out:
# Masukkan angka: 10
# 20

# %%
# fungsi len() --> panjang/jumlah data

kalimat = 'I love coding'
panjang = len(kalimat)

print(panjang)
# Out:
# 13

# %%
idea = input('Do you have an idea for a startup? ')
print(idea,'is a good idea!')
# Out:
# Do you have an idea for a startup? yess
# yess is a good idea!

# %%
def print_data(name, age):
  print('my name is', name)
  print('i am', age, 'years old')

# %%
print_data('bella', 16)
# Out:
# my name is bella
# i am 16 years old

# %% [markdown]
# ### Return Value

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
panjang = len() # int --> return value
int() # --> ubah data jadi int
str() # ubah data jadi string

var1 = str(....)

# %%
input() # return value --> String

# %%
print('haiii') # no return value --> tidak menyimpan value
# Out:
# haiii

# %%
name = input("what's your name?") # input --> has return value
print(name)
# Out:
# what's your name?bella
# bella

# %%
print(len('hello'))
# Out:
# 5

# %%
name = input('Insert your name: ')
print(name)
# Out:
# Insert your name: james
# james

# %%
print(print('tes'))
# Out:
# tes
# None

# %% [markdown]
# ### Creating functions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def nama_function(parameter):
  isi function

# %%
# tidak mengembalikan value
def print_data(nama, umur):
  print('Nama:', nama)
  print('Umur:', umur)

# manggil function
print_data('amila', 20)
print_data('frida', 16)
# Out:
# Nama: amila
# Umur: 20
# Nama: frida
# Umur: 16

# %%
# mengembalikan value
def penjumlahan(a, b):
  hasil = a + b
  return hasil

# manggil function
result = penjumlahan(6, 9) # 15
result2 = penjumlahan(5, 5)
print(result)
print(result2)
# Out:
# 15
# 10

# %%
# no return value
def print_data(name, age):
  print('my name is', name)
  print('i am', age, 'years old')

# manggil function
print_data('ahmad', 17)
# Out:
# my name is ahmad
# i am 17 years old

# %%
# return value
def penjumlahan(a, b):
  hasil = a + b
  return hasil # int/float

# manggil function penjumlahan()
jumlah = penjumlahan(3, 4)
print(jumlah)
# Out:
# 7

# %%
print("haloo")
print(5)
print(True)
# Out:
# haloo
# 5
# True

# %%
print("haloo")
# Out:
# haloo

# %%
def print_data(name, age):
  print('name:', name)
  print('age:', age)

# manggil fungsi
print_data('Rakha', 17)
# Out:
# name: Rakha
# age: 17

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def print_data(name, age):
  print('Name:', name)
  print('Age:', age)

print_data('jane', 19)
# Out:
# Name: jane
# Age: 19

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# No return value
def print_hello():
  print('Hello')

print_hello() # memanggil fungsi
# Out:
# Hello

# %%
def multiplication(a, b):
  res = a * b
  return res # ada return

result = multiplication(3, 4)
print(result)
# Out:
# 12

# %% [markdown]
# ## OOP

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# class --> deskripsi umum
class Car():
  # constructor --> function yg otomatis dipanggil waktu bikin object
  def __init__(self, color, brand):
    # property --> characteristic
    self.color = color
    self.brand = brand

  # method --> action/hal yang bisa dilakukan
  def move_forward(self):
    print('this car move forward', self.color)

# object --> benda yg dibuat dari class
red_car = Car('red', 'toyota')
red_car.move_forward()
# Out:
# this car move forward red

# %%
# object 2
yellow_car = Car('yellow', 'wuling')

yellow_car.move_forward()
# Out:
# this car move forward yellow

# %%
class Book():
  def __init__(self, title, genre): # constructor
    # property
    self.title = title
    self.genre = genre

  # method
  def print_book(self):
    print('This is', self.title)

# bikin objek
horror_book = Book('The Conjuring', 'horror')

horror_book.print_book()
# Out:
# This is The Conjuring

# %%
print(horror_book.genre)
# Out:
# horror

# %%
# class --> general description
class Car():
  def __init__(self, brand, color): # constructor
    # property
    self.brand = brand
    self.color = color

  # method
  def print_data(self):
    print('Brand:', self.brand)
    print('Color:', self.color)

# object
red_car = Car(color='red', brand='toyota')

# calling method
red_car.print_data()

# calling property
brand = red_car.brand
print(brand)
# Out:
# Brand: toyota
# Color: red
# toyota

# %%
class PriceList():
    def __init__ (self, name):
        self.name = name
        self.pricelist = dict()
    def add_price(self, product, price):
        self.pricelist[product] = price

my_offer = PriceList('Services for Instagram')
my_offer.add_price('stories', 100)

# %% [markdown]
# ## New topic: Functions with a variable number of arguments

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def

# %%
def data(d):
  for key in d:
    print(key, '-', d[key])

d = {'name': 'Rakha', 'age': 16}

data(d)
# Out:
# name - Rakha
# age - 16

# %%
def add_price(data):
    for key in data:
        print('Service –',key,', price –',data[key])

prices = {'stories':100,
          'management':1000
          }
add_price(prices)
# Out:
# Service – stories , price – 100
# Service – management , price – 1000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **kwargs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def data(d):
  for key in d:
    print(key, '-', d[key])

d = {'name': 'Rakha', 'age': 16}

data(d)
# Out:
# name - Rakha
# age - 16

# %%
def data(**dataa):
  for key in dataa:
    print(key, '-', dataa[key])

data(name='rakha', age=16, city='jakarta')
# Out:
# name - rakha
# age - 16
# city - jakarta

# %%
def add_price(**kwargs):
    for key in kwargs:
        print('Service –',key,', price –',kwargs[key])

add_price(stories = 100, management = 1000)
# Out:
# Service – stories , price – 100
# Service – management , price – 1000

# %%
class Offer():
    def add_price(self ,**kwargs):
        for key in kwargs:
            print('Service –',key,', price –',kwargs[key])

my_offer = Offer()
my_offer.add_price(stories = 100, management = 1000)
# Out:
# Service – stories , price – 100
# Service – management , price – 1000

# %%
class Price_list():
    def __init__ (self,name):
        self.name = name
        self.pricelist = dict()

    # argument --> dictionary
    def add_prices(self, **kwargs):
        for key in kwargs:
            self.pricelist[key] = kwargs[key]

my_offer = Price_list('Instagram')
my_offer.add_prices(stories = 100, management = 1000)

# %%
print(my_offer.pricelist)
# Out:
# {'stories': 100, 'management': 1000}

# %% [markdown]
# # Solutions

# %% [markdown]
# ## 2.3

# %%
#class Price_list():
class Price_list():
    def __init__ (self,name):
        self.name = name
        self.pricelist = dict()
    def add_price(self, **kwargs):
        for key in kwargs:
            self.pricelist[key] = kwargs[key]
    def order(self, **kwargs):
        sum = 0
        for key in kwargs:
            if key in self.pricelist:
                sum += self.pricelist[key] * kwargs[key]
        return sum

my_offer = Price_list('Instagram')
my_offer.add_price(management = 1000, content_plan = 850, style = 500, stories = 100, post = 300)

while input('Would you like to make an order? (1 - yes, 0 - no)') != '0':
    operation = input('Would you like to order management of your accounts (1) or posts (2)?')
    if operation == '1':
        management = int(input('How many new accounts would you like to add?'))
        content_plan = int(input('For how many of those will we create a content plan?'))
        style = int(input('For how many of those will we develop a style?'))
        price = my_offer.order(management = management, content_plan = content_plan, style = style)
    else:
        stories = int(input('How many stories would you like to order?'))
        post = int(input('How many posts would you like to order?'))
        price = my_offer.order(stories = stories, post = post)
    print(f'Service cost: {price} coins.')

print('Thank you for working with us! Have a nice day!')

# my_offer = Price_list('Instagram')
# my_offer.add_price(management = 1000, content_plan = 850, style = 500, stories = 100, post = 300)
