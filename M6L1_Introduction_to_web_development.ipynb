# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro2/blob/main/M6L1_Introduction_to_web_development.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to web development
#
# [PPT M6L1 ENG](https://docs.google.com/presentation/d/1CBx3fMLhlC6DnIQyaU7MHrFDtwNW4VHCZ22HQx6mMp4/edit?usp=sharing)

# %% [markdown]
# ## How the Internet works

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Basic HTML terms

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # HTML document structure

# %% [markdown]
# ```
#
# <!DOCTYPE html>
# <html>
# <!-- This is where the rest of the HTML code goes -->
# </html>
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# <!DOCTYPE html>
#
# <html>
#
#   <head>
#     <title>Browser</title>
#   </head>
#
#   <body>
#     <h1>
#       Write, edit and run HTML, CSS and JavaScript code online.
#     </h1>
#
#     <p>
#       Our HTML editor updates the webview automatically in real-time as you write code.
#     </p>
#   </body>
#
# </html>
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # HTML elements

# %% [markdown]
# ## no-closing tags

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# <br>
# <img src="link to image file">
# <hr>
# ```

# %% [markdown]
# ## headings

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# <h1> Heading 1 </h1>
# <h2> Heading 2 </h2>
# dst
# ```

# %% [markdown]
# ## Text Styles

# %% [markdown]
# ### Bold

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# <b> bold text </b>
# ```

# %% [markdown]
# ### Italic

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# <i> italic text </i>
# ```

# %% [markdown]
# ## List

# %% [markdown]
# ### unordered (pake -)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# <ul>
#   <li>Orange</li>
#   <li>Green</li>
#   <li>Blue</li>
# </ul>
# ```

# %% [markdown]
# ### ordered (pake angka)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# <ol>
#   <li>First</li>
#   <li>Second</li>
#   <li>Third</li>
# </ol>
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## comments

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# <!-- This is an example of a paragraph -->
# <p> Hello world! </p>
# ```

# %% [markdown]
# # Example

# %% [markdown]
# ```
# <!DOCTYPE html>
# <html>
# <!-- This is where the rest of the HTML code goes -->
#
# <head>
# 	<title> Web Developer Blog </title>
# </head>
#
# <body>
#     <h1> Hello world! </h1>
#
#     <h2> Hello world! </h2>
#
#     <h3> Hello world! </h3>
#
#     <h4> Hello world! </h4>
#
#     <h5> Hello world! </h5>
#
#     <h6> Hello world! </h6>
#
#     <p>
#     <b>This is a web page.</b> This is a web page. This is a web page. This is a web page.
#     	This is a web page. This is a web page. This is a web page. This is a web page.
#
#     haii <br>
#     <i>halooo halooo</i> <a href="https://www.google.com/">google</a>
#     </p>
#
#     <hr>
#
#     <ol>
#   		<li>Satu</li>
#         <li>Dua</li>
#     </ol>
#
#     <ul>
#   		<li>Satu</li>
#         <li>Dua</li>
#     </ul>
#
#     <img src="https://www.presidenri.go.id/assets/uploads/2020/02/presidenri.go.id-05022020111245-5e3a40bd7cdcb1.35250820-384x512.jpg">
#
#  </body>
#
# </html>
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)
